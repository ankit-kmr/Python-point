# %% [markdown]
# # Default notebook
#
# This default notebook is executed using Databricks Workflows as defined in resources/dbx_project01.job.yml.

# %%
# %sql
show databases
# Out:
# The kernel failed to start as the Python Environment 'Python 3.9.5' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
